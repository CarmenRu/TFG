# %% [markdown]
# # PARSEAMOS DRUGBANK

# %%
from funciones import parsear_drugbank as parse

xml_file = "./drugbank_all_full_database.xml/full_database.xml"
output_file = "enzimas.csv"

parse(xml_file, output_file)
# Out:
# Archivo guardado como: enzimas.csv

# %% [markdown]
# # IMPORTACIONES NECESARIAS

# %%
import pandas as pd

# %% [markdown]
# # EXPLORACION DE DATOS

# %%
df_enzimas = pd.read_csv ('enzimas.csv')

print("Drugs extracted:", len(df_enzimas))
print(df_enzimas.head())
# Out:
# Drugs extracted: 30293
#   drugbank_id  drug_name                                           synonyms  \
# 0     DB00001  Lepirudin  [Leu1, Thr2]-63-desulfohirudin|Desulfatohirudi...
# 1     DB00002  Cetuximab  Cetuximab|Cétuximab|Cetuximabum|Chimeric MoAb ...
# 2     DB00002  Cetuximab  Cetuximab|Cétuximab|Cetuximabum|Chimeric MoAb ...
# 3     DB00002  Cetuximab  Cetuximab|Cétuximab|Cetuximabum|Chimeric MoAb ...
# 4     DB00002  Cetuximab  Cetuximab|Cétuximab|Cetuximabum|Chimeric MoAb ...
#
#      type gene_name uniprot_id     action
# 0  target        F2     P00734  inhibitor
# 1  target      EGFR     P00533     binder
# 2  target    FCGR3B     O75015     binder
# 3  target      C1QA     P02745     binder
# 4  target      C1QB     P02746     binder

# %%
len(df_enzimas['drugbank_id'].unique())
# Out:
# 10162

# %%
df_filtrado = df_enzimas[df_enzimas['drug_name'].str.contains('Cetuximab', na=False)]

# %%
print(df_filtrado)
# Out:
#   drugbank_id  drug_name                                           synonyms  \
# 1     DB00002  Cetuximab  Cetuximab|Cétuximab|Cetuximabum|Chimeric MoAb ...
# 2     DB00002  Cetuximab  Cetuximab|Cétuximab|Cetuximabum|Chimeric MoAb ...
# 3     DB00002  Cetuximab  Cetuximab|Cétuximab|Cetuximabum|Chimeric MoAb ...
# 4     DB00002  Cetuximab  Cetuximab|Cétuximab|Cetuximabum|Chimeric MoAb ...
# 5     DB00002  Cetuximab  Cetuximab|Cétuximab|Cetuximabum|Chimeric MoAb ...
# 6     DB00002  Cetuximab  Cetuximab|Cétuximab|Cetuximabum|Chimeric MoAb ...
# 7     DB00002  Cetuximab  Cetuximab|Cétuximab|Cetuximabum|Chimeric MoAb ...
# 8     DB00002  Cetuximab  Cetuximab|Cétuximab|Cetuximabum|Chimeric MoAb ...
#
#      type gene_name uniprot_id  action
# 1  target      EGFR     P00533  binder
# 2  target    FCGR3B     O75015  binder
# 3  target      C1QA     P02745  binder
# 4  target      C1QB     P02746  binder
# 5  target      C1QC     P02747  binder
# 6  target    FCGR3A     P08637  binder
# 7  target    FCGR1A     P12314  binder
# 8  target    FCGR2A     P12318  binder

# %%
len(df_filtrado)
# Out:
# 8
